# %% [markdown]
# ## Parsing the Transcripts
#
# In this notebook, we are going to parse the downloaded transcripts found in the directory of the same name. This script was originally written to use the `requests` library and to fetch the transcripts from the website itself. When that failed, I used `wget` and a list of URLs to download the html files, which are here ordered by their place in the list.

# %% [markdown]
# In order to facilitate a merge, I need to elicit a **key** that these files share with other CSVs. I think the easiest is going to be to focus on the **`public_URL`**, and it looks like the following HTML will give me what I need:
#
#     <link rel="canonical" href="https://www.ted.com/talks/al_gore_on_averting_climate_crisis/transcript" />
#
# I can use BeautifulSoup to locate the `link` tag and then the `rel="canonical"` attribute, and then I'll need to chomp `/transcript` off the string.
#
# Sounds doable, yeah?

# %%
# =-=-=-=-=-=-=-=-=-=-=
# Import libraries
# =-=-=-=-=-=-=-=-=-=-= 
import pandas, re, csv, os
from bs4 import BeautifulSoup

# %% [markdown]
# ## Sandbox
#
# There's a lot going on in one line of code below, which I built up over a series of trials. To be clear, I wanted to get it down to one-line to make the `parse` function more compact. Here's a description of what happens in the series of things that happen below.
#
# Once `thesoup` object is created, `find` finds the first instance of the `<link>` tag where the `"rel"` attribute has the value "`canonical`". The `['href']` acts, as I understand it, like an index to a list, pulling out that href value, which in the case of `transcript.0` is:
#
#     https://www.ted.com/talks/al_gore_on_averting_climate_crisis/transcript
#
# We don't want the `/transcript` part of this string, since we will be merging on the main URL. Some googling and stackoverflowing revealed that the `split` method is faster than any regex we could use. Fortunately, all we needed was to peel off the part after the last slant, so this use of `rsplit('/', 1)` (reverse split) goes one slant back from the end and creates a list with two items. We want the first item in that list, and the zeroth index, `[0]`, gives us that.

# %%
# Walking through the code to get the link tag above

# Load HTML into a BS4 object
thesoup = BeautifulSoup(open("./transcripts/transcript.0"), "html5lib")

# %%
public_html = thesoup.find("link", {'rel': 'canonical'})['href'] #.rsplit('/', 1)[0]
print(public_html)

# %%
# =-=-=-=-=-=-=-=-=-=-=
# Define functions
# =-=-=-=-=-=-=-=-=-=-= 

def parse(the_soup):
    public_URL = the_soup.find("link", {'rel': 'canonical'})#['href']#.rsplit('/', 1)[0]
    speaker = ""
    duration = ""
    uploaded = ""
    views = ""
    description = ""
    for tag in the_soup.find_all("meta"):
        if tag.get("name", None) == "author":
            speaker = tag.get("content", None)
        if tag.get("itemprop", None) == "duration":
            duration = tag.get("content", None)
        if tag.get("itemprop", None) == "uploadDate":
            uploaded = tag.get("content", None)
        if tag.get("itemprop", None) == "interactionCount":
            views = tag.get("content", None)
        if tag.get("itemprop", None) == "description":
            description = tag.get("content", None)
    strung = ''.join([div.text for div in 
            the_soup.findAll("div", {"class": "Grid__cell flx-s:1 p-r:4"})])
    text   = re.sub(r"[\t]", "", strung).replace("\n", " ")
    return public_URL, speaker, duration, uploaded, views, description, text

def to_csv(the_path, out):
    # open file to write to.
    with open(out, "w") as out:
        # create csv.writer. 
        wr = csv.writer(out)
        # write our headers.
        wr.writerow(["public_URL", "speaker", "duration", "uploaded", "views", 
                     "description", "text"])
        # get all our html files.
        for the_file in os.listdir(the_path):
            with open(os.path.join(the_path, the_file)) as f:
                print(f)
                # parse the file and write the data to a row.
                wr.writerow(parse(BeautifulSoup(f, "html5lib")))

# %%
# =-=-=-=-=-=-=-=-=-=-=
# Write the CSV
# =-=-=-=-=-=-=-=-=-=-= 

to_csv("./transcripts","transcripts.csv")
# Out:
# <_io.TextIOWrapper name='./transcripts/transcript.2219' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.791' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript
mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1570' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.817' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2355' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2167' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2503' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1386' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1988' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.629' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1372' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1140' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.843' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1524' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2193' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1716' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.286' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2158' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.888' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1729' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.272' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.50' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1943' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.424' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.616' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2194' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1711' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.844' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1523' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.68' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1147' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1375' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2504' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1381' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2160' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2352' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.611' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1944' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.423' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1178' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2399' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.57' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.275' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.281' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1171' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1343' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.618' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1727' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2390' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.872' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1515' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.288' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2156' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2364' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.886' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1185' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2532' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.61' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.243' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1718' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.627' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1972' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.415' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1388' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1986' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.95' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2169' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2535' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1182' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2363' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.881' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2151' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2397' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.875' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.59' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1512' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1720' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1344' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1176' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.92' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1981' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1975' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1149' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.412' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.620' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.244' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.66' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.227' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.829' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1916' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.471' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.643' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1318' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.485' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2569' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1788' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1327' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1929' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1115' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.816' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1571' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1743' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.218' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2300' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1585' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2132' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.688' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2556' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2338' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.482' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.644' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1911' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.476' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1549' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.220' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2551' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2135' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2307' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1582' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1744' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.811' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1576' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.449' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1112' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1320' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.686' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2558' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.818' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.34' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.216' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1329' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.672' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1927' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.440' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2103' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1786' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2331' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2567' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1918' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1124' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2593' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1316' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.229' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1772' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.827' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1540' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1920' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.447' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.675' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.211' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.33' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1578' mode='r' encoding='UTF-8'>
# ...
# <_io.TextIOWrapper name='./transcripts/transcript.988' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1843' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.524' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.716' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1629' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.372' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.140' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1286' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2403' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2631' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1888' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2255' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2067' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.943' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1424' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1616' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2093' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.729' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1272' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1040' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1211' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2494' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1023' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.578' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.920' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1447' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1675' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2236' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1681' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2004' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2460' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2652' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.311' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.123' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1478' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1820' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.547' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.775' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.781' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2209' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2655' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2467' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1686' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2003' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2231' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.329' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1672' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.927' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1440' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1818' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1024' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1216' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2493' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2458' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.786' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1229' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.772' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1827' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.540' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.918' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.124' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.316' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2035' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1482' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2207' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2663' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2451' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.549' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1012' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1220' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1644' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.911' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1476' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.582' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2238' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1449' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.112' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.320' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.744' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1811' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.576' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.916' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1471' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1643' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.318' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1227' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1829' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1015' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2456' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.788' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2664' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1485' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2200' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2032' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1816' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.571' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.743' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1218' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.327' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.929' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.115' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1688' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.585' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2469' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.717' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.525' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1842' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.141' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1628' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.373' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.989' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2059' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.387' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1617' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2092' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1425' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.942' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1041' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.728' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1273' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2630' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1889' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1287' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2402' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2066' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2254' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2608' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.380' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.374' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.146' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2298' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.522' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1079' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1845' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.710' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2253' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2061' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1280' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2405' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2637' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1274' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1046' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1422' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.179' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.945' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1610' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2095' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2068' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.184' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1887' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1289' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.514' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1873' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.726' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.342' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1619' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.170' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2433' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1084' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2601' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.987' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2265' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2057' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.389' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1414' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.973' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2291' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1626' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1242' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.719' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1070' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.177' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.345' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.721' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1048' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.513' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1874' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2639' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1880' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.183' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1077' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1245' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1621' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.148' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1413' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.974' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2296' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2050' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.980' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2262' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.1083' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2606' mode='r' encoding='UTF-8'>
# <_io.TextIOWrapper name='./transcripts/transcript.2434' mode='r' encoding='UTF-8'>

# %% [markdown]
# The file throwing the error is the one after the talk by Martin Seligman, around 886.

# %%
# =-=-=-=-=-=-=-=-=-=-=
# LOAD the CSV into a Pandas dataframe to check our work
# =-=-=-=-=-=-=-=-=-=-= 

# Let python create the column names list:
with open('./test_transcripts.csv') as f:
    colnames = f.readline().strip().split(",")

# Now will import the csv as a dataframe with the column names specified
TEDtalks = pandas.read_csv('./test_transcripts.csv', names=colnames)

# Check for success:
TEDtalks.head()

# %%
URLs = TEDtalks.public_URL.tolist()

# %%
print(URLs)
