# %%
import pandas as pd

# %%
df_only = pd.read_csv('speakers_work/TEDonly_final.csv')
print(df_only.shape)
# Out:
# (992, 16)

# %%
df_only.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Talk_ID  \
# 0           0             0        1
# 1           1             1        7
# 2           2             2       53
# 3           3             3       66
# 4           4             4       92
#
#                                           public_url  \
# 0  https://www.ted.com/talks/al_gore_on_averting_...
# 1  https://www.ted.com/talks/david_pogue_says_sim...
# 2  https://www.ted.com/talks/majora_carter_s_tale...
# 3  https://www.ted.com/talks/ken_robinson_says_sc...
# 4  https://www.ted.com/talks/hans_rosling_shows_t...
#
#                           headline  \
# 0      Averting the climate crisis
# 1                 Simplicity sells
# 2              Greening the ghetto
# 3      Do schools kill creativity?
# 4  The best stats you've ever seen
#
#                                          description    event duration  \
# 0  With the same humor and humanity he exuded in ...  TED2006  0:16:17
# ...

# %%
df_plus = pd.read_csv('speakers_work/TEDplus_final.csv')
print(df_plus.shape)
# Out:
# (755, 16)

# %%
df_plus.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Talk_ID  \
# 0           0             0       37
# 1           1             1       47
# 2           2             2       98
# 3           3             3       93
# 4           4             4       39
#
#                                           public_url  \
# 0  https://www.ted.com/talks/jimmy_wales_on_the_b...
# 1  https://www.ted.com/talks/david_deutsch_on_our...
# 2  https://www.ted.com/talks/richard_dawkins_on_o...
# 3  https://www.ted.com/talks/barry_schwartz_on_th...
# 4  https://www.ted.com/talks/aubrey_de_grey_says_...
#
#                                       headline  \
# 0                       The birth of Wikipedia
# 1  Chemical scum that dream of distant quasars
# 2            Why the universe seems so strange
# 3                        The paradox of choice
# 4                       A roadmap to end aging
#
#                                          description           event duration  \
# ...

# %%
df_plus.loc[df_plus['Talk_ID'] == 2634 ]
# Out:
#      Unnamed: 0  Talk_ID                                         public_url  \
# 645         648     2634  https://www.ted.com/talks/alicia_garza_patriss...
#
#                                               headline  \
# 645  An interview with the founders of Black Lives ...
#
#                                            description          event  \
# 645  Born out of a social media post, the Black Liv...  TEDWomen 2016
#
#     duration published                                               tags  \
# 645  0:16:05  11/29/16  poverty,government,media,social media,gender e...
#
#       views  ...                              speaker2_introduction  \
# 645  840176  ...  By taking the phrase "Black Lives Matter" onto...
#
#                                       speaker2_profile         speaker_3  \
# 645  Why you should listen\nOpal Tometi is a New Yo...  Patrisse Cullors
#
#     speaker3_occupation                              speaker3_introduction  \
# ...
